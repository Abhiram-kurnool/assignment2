# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # New Section

# %%
df=pd.read_csv("/content/screen_time.csv")

# %%
df.head()
# Out:
#    Age Gender Screen Time Type Day Type  Average Screen Time (hours)  \
# 0    5   Male      Educational  Weekday                         0.44
# 1    5   Male     Recreational  Weekday                         1.11
# 2    5   Male            Total  Weekday                         1.55
# 3    5   Male      Educational  Weekend                         0.50
# 4    5   Male     Recreational  Weekend                         1.44
#
#    Sample Size
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
df.tail()
# Out:
#      Age                   Gender Screen Time Type Day Type  \
# 193   15  Other/Prefer not to say     Recreational  Weekday
# 194   15  Other/Prefer not to say            Total  Weekday
# 195   15  Other/Prefer not to say      Educational  Weekend
# 196   15  Other/Prefer not to say     Recreational  Weekend
# 197   15  Other/Prefer not to say            Total  Weekend
#
#      Average Screen Time (hours)  Sample Size
# 193                         5.16          300
# 194                         6.50          300
# 195                         2.19          300
# 196                         5.77          300
# 197                         7.96          300

# %%
df.describe()
# Out:
#               Age  Average Screen Time (hours)  Sample Size
# count  198.000000                   198.000000   198.000000
# mean    10.000000                     2.993030   400.000000
# std      3.170294                     1.922822    63.405872
# min      5.000000                     0.440000   300.000000
# 25%      7.000000                     1.402500   340.000000
# 50%     10.000000                     2.490000   400.000000
# 75%     13.000000                     4.397500   460.000000
# max     15.000000                     8.190000   500.000000

# %%
df.dtypes
# Out:
# Age                              int64
# Gender                          object
# Screen Time Type                object
# Day Type                        object
# Average Screen Time (hours)    float64
# Sample Size                      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                            0
# Gender                         0
# Screen Time Type               0
# Day Type                       0
# Average Screen Time (hours)    0
# Sample Size                    0
# dtype: int64

# %%
df['Sample Size']
# Out:
# 0      500
# 1      500
# 2      500
# 3      500
# 4      500
#       ...
# 193    300
# 194    300
# 195    300
# 196    300
# 197    300
# Name: Sample Size, Length: 198, dtype: int64

# %% [markdown]
# # Accessing specific columns

# %%
df['Average Screen Time (hours)']
# Out:
# 0      0.44
# 1      1.11
# 2      1.55
# 3      0.50
# 4      1.44
#        ...
# 193    5.16
# 194    6.50
# 195    2.19
# 196    5.77
# 197    7.96
# Name: Average Screen Time (hours), Length: 198, dtype: float64

# %%
z = df[['Age', 'Average Screen Time (hours)']]

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Average Screen Time (hours)'][1:24:2]
df[['Age', 'Average Screen Time (hours)']][0:24:2]
df.columns
# Out:
# Index(['Age', 'Gender', 'Screen Time Type', 'Day Type',
#        'Average Screen Time (hours)', 'Sample Size'],
#       dtype='object')

# %%
df.iloc[0:4]
# Out:
#    Age Gender Screen Time Type Day Type  Average Screen Time (hours)  \
# 0    5   Male      Educational  Weekday                         0.44
# 1    5   Male     Recreational  Weekday                         1.11
# 2    5   Male            Total  Weekday                         1.55
# 3    5   Male      Educational  Weekend                         0.50
#
#    Sample Size
# 0          500
# 1          500
# 2          500
# 3          500

# %%
df['Average Screen Time (hours)'] > 2
df[df['Average Screen Time (hours)'] > 2]
# Out:
#      Age                   Gender Screen Time Type Day Type  \
# 20     6                     Male            Total  Weekday
# 23     6                     Male            Total  Weekend
# 29     6                   Female            Total  Weekend
# 35     6  Other/Prefer not to say            Total  Weekend
# 38     7                     Male            Total  Weekday
# ..   ...                      ...              ...      ...
# 193   15  Other/Prefer not to say     Recreational  Weekday
# 194   15  Other/Prefer not to say            Total  Weekday
# 195   15  Other/Prefer not to say      Educational  Weekend
# 196   15  Other/Prefer not to say     Recreational  Weekend
# 197   15  Other/Prefer not to say            Total  Weekend
#
#      Average Screen Time (hours)  Sample Size
# 20                          2.02          480
# 23                          2.49          480
# 29                          2.46          480
# 35                          2.49          480
# ...

# %%
df['new'] = df['Average Screen Time (hours)'] + df['Sample Size']
df.head()
# Out:
#    Age Gender Screen Time Type Day Type  Average Screen Time (hours)  \
# 0    5   Male      Educational  Weekday                         0.44
# 1    5   Male     Recreational  Weekday                         1.11
# 2    5   Male            Total  Weekday                         1.55
# 3    5   Male      Educational  Weekend                         0.50
# 4    5   Male     Recreational  Weekend                         1.44
#
#    Sample Size     new
# 0          500  500.44
# 1          500  501.11
# 2          500  501.55
# 3          500  500.50
# 4          500  501.44

# %%
df['new2'] = df['Average Screen Time (hours)'] + 1
df
# Out:
#      Age                   Gender Screen Time Type Day Type  \
# 0      5                     Male      Educational  Weekday
# 1      5                     Male     Recreational  Weekday
# 2      5                     Male            Total  Weekday
# 3      5                     Male      Educational  Weekend
# 4      5                     Male     Recreational  Weekend
# ..   ...                      ...              ...      ...
# 193   15  Other/Prefer not to say     Recreational  Weekday
# 194   15  Other/Prefer not to say            Total  Weekday
# 195   15  Other/Prefer not to say      Educational  Weekend
# 196   15  Other/Prefer not to say     Recreational  Weekend
# 197   15  Other/Prefer not to say            Total  Weekend
#
#      Average Screen Time (hours)  Sample Size     new  new2
# 0                           0.44          500  500.44  1.44
# 1                           1.11          500  501.11  2.11
# 2                           1.55          500  501.55  2.55
# ...

# %%
df.dtypes
# Out:
# Age                              int64
# Gender                          object
# Screen Time Type                object
# Day Type                        object
# Average Screen Time (hours)    float64
# Sample Size                      int64
# new                            float64
# new2                           float64
# dtype: object

# %% [markdown]
# # Renaming columns

# %%
df = df.rename(columns={'Average Screen Time (hours)': 'Screen Time (hrs)'})

# %%
df
# Out:
#      Age                   Gender Screen Time Type Day Type  \
# 0      5                     Male      Educational  Weekday
# 1      5                     Male     Recreational  Weekday
# 2      5                     Male            Total  Weekday
# 3      5                     Male      Educational  Weekend
# 4      5                     Male     Recreational  Weekend
# ..   ...                      ...              ...      ...
# 193   15  Other/Prefer not to say     Recreational  Weekday
# 194   15  Other/Prefer not to say            Total  Weekday
# 195   15  Other/Prefer not to say      Educational  Weekend
# 196   15  Other/Prefer not to say     Recreational  Weekend
# 197   15  Other/Prefer not to say            Total  Weekend
#
#      Screen Time (hrs)  Sample Size     new  new2
# 0                 0.44          500  500.44  1.44
# 1                 1.11          500  501.11  2.11
# 2                 1.55          500  501.55  2.55
# ...

# %%
df['Screen Time (hrs)'][0:10]
# Out:
# 0    0.44
# 1    1.11
# 2    1.55
# 3    0.50
# 4    1.44
# 5    1.93
# 6    0.49
# 7    0.96
# 8    1.45
# 9    0.50
# Name: Screen Time (hrs), dtype: float64

# %%
df.plot(x='Screen Time (hrs)', y='Age', kind='line')
# Out:
# <Axes: xlabel='Screen Time (hrs)'>

# %%
df.plot(x='Screen Time (hrs)', y='Age', kind='bar')
# Out:
# <Axes: xlabel='Screen Time (hrs)'>

# %%
df['Screen Time (hrs)'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sample Size'].plot(kind='hist')
plt.show()

# %%
plt.show()
